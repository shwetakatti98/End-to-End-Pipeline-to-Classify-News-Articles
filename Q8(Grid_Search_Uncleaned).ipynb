# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import pickle
from collections import Counter, defaultdict
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from nltk.stem import *

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.utils.extmath import randomized_svd
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv("dataset.csv")
print('Number of data points : ', df.shape[0])
print('Number of features : ', df.shape[1])
df.head()
# Out:
# Number of data points :  2072
# Number of features :  9
#    Unnamed: 0                                          full_text  \
# 0         590  Having made a massive impact in Saudi Arabia w...
# 1         388  Cricket is all about the emotional rollercoast...
# 2         423  New Zealand announces back-to-back tours next ...
# 3         563  It's not the first time cricket fans in the co...
# 4         634  An employee works on a computer terminal again...
#
#                                              summary  \
# 0  Having made a massive impact in Saudi Arabia w...
# 1  No matter which team fans hope to win, every s...
# 2  New Zealand announces back-to-back tours next ...
# 3  Billed as one of the pre-tournament favourites...
# 4  REUTERS/Sivaram VBENGALURU, Oct 11 (Reuters Br...
#
#                                             keywords         publish_date  \
# 0  ['singhs', 'rooting', 'cool', 'saudi', 'style'...                  NaN
# 1  ['wants', 'fans', 'finals', 'cup', 'win', 'tou...                  NaN
# 2  ['test', 'west', 'tour', 'zealand', 'world', '...  2021-12-20 00:00:00
# 3  ['qualify', 'afghanistan', 'cup', 'world', 'ze...                  NaN
# 4  ['success', 'tech', 'startup', 'talent', 'onli...  2021-10-11 00:00:00
#
#           authors                                                url  \
# 0              []  https://www.msn.com/en-in/entertainment/other/...
# 1              []  https://www.prnewswire.com:443/news-releases/c...
# 2              []  https://www.aljazeera.com/news/2021/12/20/cric...
# 3              []  https://www.msn.com/en-in/news/other/t20-world...
# 4  ['Una Galani']  https://www.reuters.com/breakingviews/india-in...
#
#   leaf_label root_label
# 0    cricket     sports
# 1    cricket     sports
# 2    cricket     sports
# 3    cricket     sports
# 4    cricket     sports

# %%
train, test = train_test_split(df[["full_text","root_label"]], test_size=0.2)

# %%
print('Number of data points in train data:', train.shape[0])
print('Number of data points in test data:', test.shape[0])
# Out:
# Number of data points in train data: 1657
# Number of data points in test data: 415

# %% [markdown]
# # Cleanup

# %%
import re
def clean(text):
    text = re.sub(r"http\S+", '', text, flags=re.MULTILINE)
    texter = re.sub(r"<br />", " ", text)
    texter = re.sub(r"&quot;", "\"",texter)
    texter = re.sub('&#39;', "\"", texter)
    texter = re.sub('\n', " ", texter)
    texter = re.sub(' u '," you ", texter)
    texter = re.sub('`',"", texter)
    texter = re.sub(' +', ' ', texter)
    texter = re.sub(r"(!)\1+", r"!", texter)
    texter = re.sub(r"(\?)\1+", r"?", texter)
    texter = re.sub('&amp;', 'and', texter)
    texter = re.sub('\r', ' ',texter)
    texter = re.sub(r"[0-9]","", texter)
    texter = re.sub('[^a-zA-Z0-9\n]', ' ', texter)
    texter = re.sub('\s+',' ', texter)
    texter = texter.lower()
    clean = re.compile('<.*?>')
    texter = texter.encode('ascii', 'ignore').decode('ascii')
    texter = re.sub(clean, '', texter)
    if texter == "":
        texter = ""
    return texter

# %%
train_clean = train.copy()

# %%
train_clean
# Out:
#                                               full_text root_label
# 1626  Coal mining authorities say that one miner is ...    climate
# 23    © Nikhil Naz Virat Kohli to play ODIs in South...     sports
# 880   Play Magnus Group to Bring Chess NFTs to Marke...     sports
# 1040  This holiday season, The Save Movement is urgi...    climate
# 950   Queens, NY – James Todd Smith — better known a...     sports
# ...                                                 ...        ...
# 303   Seacrest out, Ted Lasso in. Ryan Seacrest and ...     sports
# 1012  Citrusw00d Productions unveils films minted as...     sports
# 267   FILE - Tennessee Titans running back Derrick H...     sports
# 1763  A swarm of earthquakes has been rattling the o...    climate
# 1588  A very strong 5.5 earthquake was just recorded...    climate
#
# [1657 rows x 2 columns]

# %%
trail = train_clean.copy()

# %%
trail
# Out:
#                                               full_text root_label
# 1626  Coal mining authorities say that one miner is ...    climate
# 23    © Nikhil Naz Virat Kohli to play ODIs in South...     sports
# 880   Play Magnus Group to Bring Chess NFTs to Marke...     sports
# 1040  This holiday season, The Save Movement is urgi...    climate
# 950   Queens, NY – James Todd Smith — better known a...     sports
# ...                                                 ...        ...
# 303   Seacrest out, Ted Lasso in. Ryan Seacrest and ...     sports
# 1012  Citrusw00d Productions unveils films minted as...     sports
# 267   FILE - Tennessee Titans running back Derrick H...     sports
# 1763  A swarm of earthquakes has been rattling the o...    climate
# 1588  A very strong 5.5 earthquake was just recorded...    climate
#
# [1657 rows x 2 columns]

# %%
train_clean = train_clean['full_text'].apply(clean)

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk import pos_tag
from pickle import dump

counts = []

wnl = nltk.wordnet.WordNetLemmatizer()
analyzer = CountVectorizer().build_analyzer()

def penn2morphy(penntag):
    """ Converts Penn Treebank tags to WordNet. """
    morphy_tag = {'NN':'n', 'JJ':'a',
                  'VB':'v', 'RB':'r'}
    try:
        return morphy_tag[penntag[:2]]
    except:
        return 'n'

def lemmatize_sent(list_word):
    # Text input is string, returns array of lowercased strings(words).
    return [wnl.lemmatize(word.lower(), pos=penn2morphy(tag)) 
            for word, tag in pos_tag(list_word)]


def rmv_nums(doc):
    #gets rid of numbers including floats
    #does lemmatization with nltk.wordnet.WordNetLemmatizer and pos_tag
    return (word for word in lemmatize_sent(analyzer(doc)) 
            if not word.isdigit())

#CountVectorizer returns a callable that handles preprocessing and tokenization
#Use the “english” stopwords of the CountVectorizer
vectorizer=CountVectorizer(analyzer=rmv_nums,min_df=3,stop_words='english')

#do feature extraction (train):
X_train_counts=vectorizer.fit_transform(train["full_text"]) #get matrix of doc-term counts (training data)
print('Size of training data after lemmatization but before TF-IDF: ', X_train_counts.shape) 
X_test_counts=vectorizer.transform(test["full_text"]) 
print('Size of testing data after lemmatization but before TF-IDF:  ', X_test_counts.shape) 

from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print('Shape of train TF-IDF matrix: ',X_train_tfidf.shape)
X_test_tfidf = tfidf_transformer.transform(X_test_counts)
print('Shape of test TF-IDF matrix:  ',X_test_tfidf.shape)
# Out:
# Size of training data after lemmatization but before TF-IDF:  (1657, 10270)
# Size of testing data after lemmatization but before TF-IDF:   (415, 10270)
# Shape of train TF-IDF matrix:  (1657, 10270)
# Shape of test TF-IDF matrix:   (415, 10270)

# %%
y_train_encoded = train["root_label"].copy()
y_test_encoded = test["root_label"].copy()

y_train_encoded[y_train_encoded == 'sports'] = 0
y_test_encoded[y_test_encoded == 'sports'] = 0


y_train_encoded[y_train_encoded== 'climate'] = 1
y_test_encoded[y_test_encoded == 'climate'] = 1

print("Training Set\n")
print("Original train_dataset:\n" + str(train["root_label"][0:20]))
print("\nBinarized train_dataset:\n" + str(y_train_encoded[0:20]))
print("\nTest Set\n")
print("Original test_dataset:\n" + str(test["root_label"][0:20]))
print("\nBinarized test_dataset:\n" + str(y_test_encoded[0:20]))
# Out:
# Training Set
#
# Original train_dataset:
# 1626    climate
# 23       sports
# 880      sports
# 1040    climate
# 950      sports
# 147      sports
# 1338    climate
# 1487    climate
# 89       sports
# 552      sports
# 1816    climate
# 1523    climate
# 510      sports
# 1653    climate
# 901      sports
# 1740    climate
# 1945    climate
# 1700    climate
# 1710    climate
# 149      sports
# Name: root_label, dtype: object
#
# Binarized train_dataset:
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
# 147     0
# 1338    1
# 1487    1
# 89      0
# 552     0
# 1816    1
# 1523    1
# 510     0
# 1653    1
# 901     0
# 1740    1
# 1945    1
# 1700    1
# 1710    1
# 149     0
# Name: root_label, dtype: object
#
# Test Set
#
# Original test_dataset:
# 61       sports
# 733      sports
# 1274    climate
# 767      sports
# 1738    climate
# 1909    climate
# 1154    climate
# 1022     sports
# 1500    climate
# 1296    climate
# 275      sports
# 1178    climate
# 746      sports
# 1076    climate
# 607      sports
# 1559    climate
# 611      sports
# 982      sports
# 743      sports
# 1684    climate
# Name: root_label, dtype: object
#
# Binarized test_dataset:
# 61      0
# 733     0
# 1274    1
# 767     0
# 1738    1
# 1909    1
# 1154    1
# 1022    0
# 1500    1
# 1296    1
# 275     0
# 1178    1
# 746     0
# 1076    1
# 607     0
# 1559    1
# 611     0
# 982     0
# 743     0
# 1684    1
# Name: root_label, dtype: object

# %%
wnl = nltk.wordnet.WordNetLemmatizer()

def penn2morphy(penntag):
    """ Converts Penn Treebank tags to WordNet. """
    morphy_tag = {'NN':'n', 'JJ':'a',
                  'VB':'v', 'RB':'r'}
    try:
        return morphy_tag[penntag[:2]]
    except:
        return 'n'

def lemmatize_sent(list_word):
    return [wnl.lemmatize(word.lower(), pos=penn2morphy(tag)) 
            for word, tag in pos_tag(list_word)]

# %%
analyzer = CountVectorizer().build_analyzer()
stemmer = PorterStemmer()
def stemmed (doc):
    return (stemmer.stem(word) for word in analyzer(doc) if not word.isdigit())

def lemma(doc):
    return (word for word in lemmatize_sent(analyzer(doc)) if not word.isdigit())

def nolemma(doc):
    return (word for word in analyzer(doc) if not word.isdigit())

# %%
vectorizer_df3_lemma = CountVectorizer(min_df=3, 
                             analyzer=lemma, 
                             stop_words='english')
vectorizer_df5_lemma = CountVectorizer(min_df=5, 
                             analyzer=lemma, 
                             stop_words='english')
vectorizer_df3_nolemma = CountVectorizer(min_df=3, 
                             analyzer=nolemma, 
                             stop_words='english')
vectorizer_df5_nolemma = CountVectorizer(min_df=5, 
                             analyzer=nolemma, 
                             stop_words='english')
vectorizer_df3_stem = CountVectorizer(min_df=3, 
                             analyzer=stemmed, 
                             stop_words='english')
vectorizer_df5_stem = CountVectorizer(min_df=5, 
                             analyzer=stemmed, 
                             stop_words='english')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import TruncatedSVD, NMF

# used to cache results
from tempfile import mkdtemp
from shutil import rmtree
import joblib
from joblib import Memory

# print(__doc__)
location = mkdtemp()
memory = Memory(location=location, verbose=10)

pipeline0 = Pipeline([
    ('vect', vectorizer_df3_lemma),
    ('tfidf', TfidfTransformer()),
    ('reduce_dim', TruncatedSVD(n_components=50, random_state=42)),
    ('clf', SVC(kernel='linear', C=1)),
],
memory=memory
)

param_grid0 = [
    {
        'vect': [vectorizer_df3_stem, 
                 vectorizer_df5_stem,
                 vectorizer_df3_lemma, 
                 vectorizer_df3_nolemma, 
                 vectorizer_df5_lemma, 
                 vectorizer_df5_nolemma],
        'reduce_dim': [TruncatedSVD(n_components=5, random_state=42),
                       NMF(n_components=5, init='random', random_state=42, max_iter=10000)],
        'clf': [SVC(kernel='linear', C=1.0,max_iter=10000), 
                LogisticRegression(penalty='l1', C=10,max_iter=10000, solver='liblinear'), 
                LogisticRegression(penalty='l2', C=100,max_iter=10000, solver = 'liblinear'),
                GaussianNB()]
    }
]
grid0 = GridSearchCV(pipeline0, cv=5, n_jobs=1, param_grid=param_grid0, scoring='accuracy')
grid0.fit(train['full_text'], y_train_encoded.astype(str).astype(int))
rmtree(location)
# Out:
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.0s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8048 sparse matrix of type '<class 'numpy.int64'>'
# 	with 248638 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1325x8048 sparse matrix of type '<class 'numpy.float64'>'
# 	with 248638 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.3s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8021 sparse matrix of type '<class 'numpy.int64'>'
# 	with 251704 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1325x8021 sparse matrix of type '<class 'numpy.float64'>'
# 	with 251704 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8024 sparse matrix of type '<class 'numpy.int64'>'
# 	with 249406 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x8024 sparse matrix of type '<class 'numpy.float64'>'
# 	with 249406 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8044 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250212 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x8044 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250212 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8158 sparse matrix of type '<class 'numpy.int64'>'
# 	with 251640 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x8158 sparse matrix of type '<class 'numpy.float64'>'
# 	with 251640 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 7.9s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x5641 sparse matrix of type '<class 'numpy.int64'>'
# 	with 240525 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1325x5641 sparse matrix of type '<class 'numpy.float64'>'
# 	with 240525 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x5667 sparse matrix of type '<class 'numpy.int64'>'
# 	with 243767 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1325x5667 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243767 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x5661 sparse matrix of type '<class 'numpy.int64'>'
# 	with 241433 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x5661 sparse matrix of type '<class 'numpy.float64'>'
# 	with 241433 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x5669 sparse matrix of type '<class 'numpy.int64'>'
# 	with 242206 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x5669 sparse matrix of type '<class 'numpy.float64'>'
# 	with 242206 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x5724 sparse matrix of type '<class 'numpy.int64'>'
# 	with 243453 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x5724 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243453 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.1s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8984 sparse matrix of type '<class 'numpy.int64'>'
# 	with 243688 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1325x8984 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243688 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.8s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8977 sparse matrix of type '<class 'numpy.int64'>'
# 	with 246701 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1325x8977 sparse matrix of type '<class 'numpy.float64'>'
# 	with 246701 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.5s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8944 sparse matrix of type '<class 'numpy.int64'>'
# 	with 244378 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x8944 sparse matrix of type '<class 'numpy.float64'>'
# 	with 244378 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.9s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8995 sparse matrix of type '<class 'numpy.int64'>'
# 	with 245156 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x8995 sparse matrix of type '<class 'numpy.float64'>'
# 	with 245156 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 19.1s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x9101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 246531 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x9101 sparse matrix of type '<class 'numpy.float64'>'
# 	with 246531 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.4s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x11274 sparse matrix of type '<class 'numpy.int64'>'
# 	with 259228 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1325x11274 sparse matrix of type '<class 'numpy.float64'>'
# 	with 259228 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x11323 sparse matrix of type '<class 'numpy.int64'>'
# 	with 262808 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1325x11323 sparse matrix of type '<class 'numpy.float64'>'
# 	with 262808 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x11269 sparse matrix of type '<class 'numpy.int64'>'
# 	with 260430 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x11269 sparse matrix of type '<class 'numpy.float64'>'
# 	with 260430 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x11332 sparse matrix of type '<class 'numpy.int64'>'
# 	with 261451 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1326x11332 sparse matrix of type '<class 'numpy.float64'>'
# 	with 261451 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x11463 sparse matrix of type '<class 'numpy.int64'>'
# 	with 262638 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# ...
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/6fb66a8732ca7957de2648b2ce6f20c6
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/68bd60abd5e7fd4c73cf9fb342888199
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/9ee379502f029d2fefdb99e14910de9a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/68cd4495c82a8b595723d2f144aa7723
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/9d75e26a8ac8b5414e7e9b76bd9c4d28
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/e3c0584d2d0f892838dc929cfec82f08
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/ccd9c0fcb7948d576c084d05ce1e0f43
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/90995e5f3922d61beb98b33025a101fc
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/6cc2a2580e287ad55f2b83364f9f293c
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/c67c070de4fed20c75085d71dcc5a5d1
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/92da76a90960598bff46e14c10126f1c
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/5c5b2e45bc946220c27489515d5f544d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/cdc49d5abe245d98c969e79a02a9d5f5
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/7bca725c07d604d9ad6f5cf0d761c026
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/b345c780e7f97b40cb2223b19beadb93
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/fff76d44f271976c07891318d3c40883
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/b8d6c5ef8e5c3ccafaf840b119b7122d
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/9259240f2a8f7e078986239baa62868a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/0bf546837e853e4282bdec362698df61
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/e98f9c10b170c4650f90b356108185e4
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/197ee628d132eeb011eec78130a00fd9
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/c6d17aa26f3e25d59b33fb4bc123d6d7
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/f446de286d4e7f5a7fd2c73cdba0bc50
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/e3da0403613e0f14fdb7795c8032a3ca
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/fbb5de1ae8f0ed9e6a71d0485eb92a85
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/9a99d4cecb18614fca7d7b2703002d87
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/78bc1ed517a1a5e4701434be6e4bb5ce
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/8692ee0f715d96025d33273bc4e03307
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/81d9fe590b58ab8fe1439b3e1a9a6ca0
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/7059a84516137dea0e83191d1e786140
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/e30010c3f622f6259f33507b598bb69e
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/853fd1756d56f24955fb21712de048ec
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/cf76d826d382c33eea6803df5b814985
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/2010580b6c213968e06edcfad753010d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/794eb5a0ae91647e42e711846b4c1656
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/8cca71ba4df6124937165ead3bf265b9
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/14ab1789eec4c1b19167f7c922c4fe59
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/3d4c0f557ee5ca2eb8a235646d3ea992
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/36cd7d6eb6da591bd728b95fb7ad6507
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/3631d9cc96c88c16a3d411e5597cb077
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/1c25feb28a618241d6519188e590d52b
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/e3dfc4442288e845bb394e066d794e2a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/f1ff20df6e3f35bb27b5b45c38ee51a6
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/3f9ed141564fd7cfa2d7b2ad14a2e60b
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/af121261c6ee7d5defb3771ee1fd37e2
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/0af2170c0758669641f0a5235eecb76f
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/5e2d122fd6be5930aa4f850278d6ec75
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/7c4de9c5ddc5407821fc0ee8bec27952
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmp887uc00a/joblib/sklearn/pipeline/_fit_transform_one/b6720684ad8b580026506b8f255d9d17
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1657, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1657, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 10.1s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1657x6386 sparse matrix of type '<class 'numpy.int64'>'
# 	with 306043 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1657, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=5, random_state=42), <1657x6386 sparse matrix of type '<class 'numpy.float64'>'
# 	with 306043 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1657, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min

# %%
gg0 = pd.DataFrame(grid0.cv_results_)

# %%
gg00 = gg0.sort_values(by='mean_test_score',ascending=False)
gg00
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 25       0.075437      0.000911         2.002199        0.092823
# 13       0.075936      0.000732         1.997829        0.095103
# 17       0.093485      0.001213         0.083722        0.003663
# 15       0.095489      0.001412         0.084397        0.003628
# 29       0.091587      0.001193         0.083836        0.003853
# 26       0.086722      0.001053         4.670132        0.223706
# 14       0.085103      0.001052         4.638866        0.209409
# 21       0.096783      0.001995         0.089148        0.003090
# 24       0.078035      0.000794         2.001578        0.094888
# 12       0.079151      0.000962         1.998965        0.096379
# 19       0.076529      0.001314         2.000170        0.095387
# 27       0.094293      0.000930         0.084272        0.003736
# 16       0.082523      0.001275         4.634867        0.206144
# 23       0.094026      0.002725         0.087541        0.003456
# 22       0.082837      0.001600         4.646175        0.214797
# 43       0.075404      0.001119         2.014027        0.091024
# 31       0.075544      0.001066         2.001044        0.096585
# 46       0.081200      0.001986         4.633298        0.205690
# 28       0.085997      0.004053         4.671976        0.207143
# 20       0.085799      0.001222         4.671619        0.184794
# 2       18.901177      0.349189         4.658276        0.187383
# 34       0.082673      0.002323         4.641506        0.208760
# 0        8.355661      0.089822         1.992732        0.092999
# 18       0.079793      0.002159         2.001913        0.096507
# 35       0.091676      0.000912         0.087401        0.003620
# 1        8.292810      0.087632         1.999678        0.085585
# 3        0.707505      0.007019         0.092983        0.003580
# 4       19.007058      0.248739         4.693899        0.221285
# 5        0.685244      0.007119         0.090880        0.003394
# 30       0.078219      0.001610         2.002998        0.095943
# 47       0.091489      0.001009         0.087702        0.003606
# 38       0.083879      0.000901         4.639004        0.209348
# 32       0.085570      0.001394         4.658862        0.206699
# 33       0.097625      0.002733         0.088767        0.003096
# 40       0.081631      0.001642         4.631398        0.209923
# 36       0.077676      0.001381         1.998848        0.094823
# 42       0.077578      0.000590         2.000555        0.096668
# 41       0.091004      0.001553         0.083934        0.003450
# 44       0.084261      0.001035         4.667912        0.230359
# 45       0.094699      0.000977         0.088486        0.003590
# 39       0.094817      0.002142         0.084468        0.003459
# 37       0.074591      0.001091         1.998009        0.097308
# 7        0.313028      0.025800         2.019556        0.097638
# 6        0.325839      0.024565         2.024323        0.098300
# 10       0.272927      0.044199         4.672440        0.190622
# 8        0.474865      0.177614         4.673153        0.211819
# 9        0.667753      0.237984         0.101364        0.005780
# 11       0.427771      0.158234         0.097759        0.003767
#
#                                             param_clf  \
# 25  LogisticRegression(C=100, max_iter=10000, solv...
# 13  LogisticRegression(C=10, max_iter=10000, penal...
# 17  LogisticRegression(C=10, max_iter=10000, penal...
# 15  LogisticRegression(C=10, max_iter=10000, penal...
# 29  LogisticRegression(C=100, max_iter=10000, solv...
# 26  LogisticRegression(C=100, max_iter=10000, solv...
# 14  LogisticRegression(C=10, max_iter=10000, penal...
# 21  LogisticRegression(C=10, max_iter=10000, penal...
# 24  LogisticRegression(C=100, max_iter=10000, solv...
# 12  LogisticRegression(C=10, max_iter=10000, penal...
# 19  LogisticRegression(C=10, max_iter=10000, penal...
# 27  LogisticRegression(C=100, max_iter=10000, solv...
# 16  LogisticRegression(C=10, max_iter=10000, penal...
# 23  LogisticRegression(C=10, max_iter=10000, penal...
# 22  LogisticRegression(C=10, max_iter=10000, penal...
# 43                                       GaussianNB()
# 31  LogisticRegression(C=100, max_iter=10000, solv...
# 46                                       GaussianNB()
# 28  LogisticRegression(C=100, max_iter=10000, solv...
# 20  LogisticRegression(C=10, max_iter=10000, penal...
# 2                SVC(kernel='linear', max_iter=10000)
# 34  LogisticRegression(C=100, max_iter=10000, solv...
# 0                SVC(kernel='linear', max_iter=10000)
# 18  LogisticRegression(C=10, max_iter=10000, penal...
# 35  LogisticRegression(C=100, max_iter=10000, solv...
# 1                SVC(kernel='linear', max_iter=10000)
# 3                SVC(kernel='linear', max_iter=10000)
# 4                SVC(kernel='linear', max_iter=10000)
# 5                SVC(kernel='linear', max_iter=10000)
# 30  LogisticRegression(C=100, max_iter=10000, solv...
# 47                                       GaussianNB()
# 38                                       GaussianNB()
# 32  LogisticRegression(C=100, max_iter=10000, solv...
# 33  LogisticRegression(C=100, max_iter=10000, solv...
# 40                                       GaussianNB()
# 36                                       GaussianNB()
# 42                                       GaussianNB()
# 41                                       GaussianNB()
# 44                                       GaussianNB()
# 45                                       GaussianNB()
# 39                                       GaussianNB()
# 37                                       GaussianNB()
# 7                SVC(kernel='linear', max_iter=10000)
# 6                SVC(kernel='linear', max_iter=10000)
# 10               SVC(kernel='linear', max_iter=10000)
# 8                SVC(kernel='linear', max_iter=10000)
# 9                SVC(kernel='linear', max_iter=10000)
# 11               SVC(kernel='linear', max_iter=10000)
#
#                                      param_reduce_dim  \
# 25      TruncatedSVD(n_components=5, random_state=42)
# 13      TruncatedSVD(n_components=5, random_state=42)
# 17      TruncatedSVD(n_components=5, random_state=42)
# 15      TruncatedSVD(n_components=5, random_state=42)
# 29      TruncatedSVD(n_components=5, random_state=42)
# 26      TruncatedSVD(n_components=5, random_state=42)
# 14      TruncatedSVD(n_components=5, random_state=42)
# 21  NMF(init='random', max_iter=10000, n_component...
# 24      TruncatedSVD(n_components=5, random_state=42)
# 12      TruncatedSVD(n_components=5, random_state=42)
# 19  NMF(init='random', max_iter=10000, n_component...
# 27      TruncatedSVD(n_components=5, random_state=42)
# 16      TruncatedSVD(n_components=5, random_state=42)
# 23  NMF(init='random', max_iter=10000, n_component...
# 22  NMF(init='random', max_iter=10000, n_component...
# 43  NMF(init='random', max_iter=10000, n_component...
# 31  NMF(init='random', max_iter=10000, n_component...
# 46  NMF(init='random', max_iter=10000, n_component...
# 28      TruncatedSVD(n_components=5, random_state=42)
# 20  NMF(init='random', max_iter=10000, n_component...
# 2       TruncatedSVD(n_components=5, random_state=42)
# 34  NMF(init='random', max_iter=10000, n_component...
# 0       TruncatedSVD(n_components=5, random_state=42)
# 18  NMF(init='random', max_iter=10000, n_component...
# 35  NMF(init='random', max_iter=10000, n_component...
# 1       TruncatedSVD(n_components=5, random_state=42)
# 3       TruncatedSVD(n_components=5, random_state=42)
# 4       TruncatedSVD(n_components=5, random_state=42)
# 5       TruncatedSVD(n_components=5, random_state=42)
# 30  NMF(init='random', max_iter=10000, n_component...
# 47  NMF(init='random', max_iter=10000, n_component...
# 38      TruncatedSVD(n_components=5, random_state=42)
# 32  NMF(init='random', max_iter=10000, n_component...
# 33  NMF(init='random', max_iter=10000, n_component...
# 40      TruncatedSVD(n_components=5, random_state=42)
# 36      TruncatedSVD(n_components=5, random_state=42)
# 42  NMF(init='random', max_iter=10000, n_component...
# 41      TruncatedSVD(n_components=5, random_state=42)
# 44  NMF(init='random', max_iter=10000, n_component...
# 45  NMF(init='random', max_iter=10000, n_component...
# 39      TruncatedSVD(n_components=5, random_state=42)
# 37      TruncatedSVD(n_components=5, random_state=42)
# 7   NMF(init='random', max_iter=10000, n_component...
# 6   NMF(init='random', max_iter=10000, n_component...
# 10  NMF(init='random', max_iter=10000, n_component...
# 8   NMF(init='random', max_iter=10000, n_component...
# 9   NMF(init='random', max_iter=10000, n_component...
# 11  NMF(init='random', max_iter=10000, n_component...
#
#                                            param_vect  \
# 25  CountVectorizer(analyzer=<function stemmed at ...
# 13  CountVectorizer(analyzer=<function stemmed at ...
# 17  CountVectorizer(analyzer=<function nolemma at ...
# 15  CountVectorizer(analyzer=<function nolemma at ...
# 29  CountVectorizer(analyzer=<function nolemma at ...
# 26  CountVectorizer(analyzer=<function lemma at 0x...
# 14  CountVectorizer(analyzer=<function lemma at 0x...
# 21  CountVectorizer(analyzer=<function nolemma at ...
# 24  CountVectorizer(analyzer=<function stemmed at ...
# 12  CountVectorizer(analyzer=<function stemmed at ...
# 19  CountVectorizer(analyzer=<function stemmed at ...
# 27  CountVectorizer(analyzer=<function nolemma at ...
# 16  CountVectorizer(analyzer=<function lemma at 0x...
# 23  CountVectorizer(analyzer=<function nolemma at ...
# 22  CountVectorizer(analyzer=<function lemma at 0x...
# 43  CountVectorizer(analyzer=<function stemmed at ...
# 31  CountVectorizer(analyzer=<function stemmed at ...
# 46  CountVectorizer(analyzer=<function lemma at 0x...
# 28  CountVectorizer(analyzer=<function lemma at 0x...
# 20  CountVectorizer(analyzer=<function lemma at 0x...
# 2   CountVectorizer(analyzer=<function lemma at 0x...
# 34  CountVectorizer(analyzer=<function lemma at 0x...
# 0   CountVectorizer(analyzer=<function stemmed at ...
# 18  CountVectorizer(analyzer=<function stemmed at ...
# 35  CountVectorizer(analyzer=<function nolemma at ...
# 1   CountVectorizer(analyzer=<function stemmed at ...
# 3   CountVectorizer(analyzer=<function nolemma at ...
# 4   CountVectorizer(analyzer=<function lemma at 0x...
# 5   CountVectorizer(analyzer=<function nolemma at ...
# 30  CountVectorizer(analyzer=<function stemmed at ...
# 47  CountVectorizer(analyzer=<function nolemma at ...
# 38  CountVectorizer(analyzer=<function lemma at 0x...
# 32  CountVectorizer(analyzer=<function lemma at 0x...
# 33  CountVectorizer(analyzer=<function nolemma at ...
# 40  CountVectorizer(analyzer=<function lemma at 0x...
# 36  CountVectorizer(analyzer=<function stemmed at ...
# 42  CountVectorizer(analyzer=<function stemmed at ...
# 41  CountVectorizer(analyzer=<function nolemma at ...
# 44  CountVectorizer(analyzer=<function lemma at 0x...
# 45  CountVectorizer(analyzer=<function nolemma at ...
# 39  CountVectorizer(analyzer=<function nolemma at ...
# 37  CountVectorizer(analyzer=<function stemmed at ...
# 7   CountVectorizer(analyzer=<function stemmed at ...
# 6   CountVectorizer(analyzer=<function stemmed at ...
# 10  CountVectorizer(analyzer=<function lemma at 0x...
# 8   CountVectorizer(analyzer=<function lemma at 0x...
# 9   CountVectorizer(analyzer=<function nolemma at ...
# 11  CountVectorizer(analyzer=<function nolemma at ...
#
#                                                params  split0_test_score  \
# 25  {'clf': LogisticRegression(C=100, max_iter=100...           0.918675
# 13  {'clf': LogisticRegression(C=10, max_iter=1000...           0.921687
# 17  {'clf': LogisticRegression(C=10, max_iter=1000...           0.912651
# 15  {'clf': LogisticRegression(C=10, max_iter=1000...           0.912651
# 29  {'clf': LogisticRegression(C=100, max_iter=100...           0.912651
# 26  {'clf': LogisticRegression(C=100, max_iter=100...           0.900602
# 14  {'clf': LogisticRegression(C=10, max_iter=1000...           0.900602
# 21  {'clf': LogisticRegression(C=10, max_iter=1000...           0.900602
# 24  {'clf': LogisticRegression(C=100, max_iter=100...           0.897590
# 12  {'clf': LogisticRegression(C=10, max_iter=1000...           0.900602
# 19  {'clf': LogisticRegression(C=10, max_iter=1000...           0.909639
# 27  {'clf': LogisticRegression(C=100, max_iter=100...           0.906627
# 16  {'clf': LogisticRegression(C=10, max_iter=1000...           0.903614
# 23  {'clf': LogisticRegression(C=10, max_iter=1000...           0.894578
# 22  {'clf': LogisticRegression(C=10, max_iter=1000...           0.903614
# 43  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.891566
# 31  {'clf': LogisticRegression(C=100, max_iter=100...           0.894578
# 46  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.906627
# 28  {'clf': LogisticRegression(C=100, max_iter=100...           0.903614
# 20  {'clf': LogisticRegression(C=10, max_iter=1000...           0.894578
# 2   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.885542
# 34  {'clf': LogisticRegression(C=100, max_iter=100...           0.891566
# 0   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.885542
# 18  {'clf': LogisticRegression(C=10, max_iter=1000...           0.891566
# 35  {'clf': LogisticRegression(C=100, max_iter=100...           0.888554
# 1   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.885542
# 3   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.879518
# 4   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.882530
# 5   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.876506
# 30  {'clf': LogisticRegression(C=100, max_iter=100...           0.876506
# 47  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.882530
# 38  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.870482
# 32  {'clf': LogisticRegression(C=100, max_iter=100...           0.882530
# 33  {'clf': LogisticRegression(C=100, max_iter=100...           0.873494
# 40  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.873494
# 36  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.864458
# 42  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.888554
# 41  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.870482
# 44  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.894578
# 45  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.882530
# 39  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.861446
# 37  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.855422
# 7   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.834337
# 6   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.813253
# 10  {'clf': SVC(kernel='linear', max_iter=10000), ...           0.807229
# 8   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.807229
# 9   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.819277
# 11  {'clf': SVC(kernel='linear', max_iter=10000), ...           0.807229
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 25           0.936747           0.915408           0.924471
# 13           0.933735           0.915408           0.924471
# 17           0.933735           0.912387           0.915408
# 15           0.933735           0.912387           0.915408
# 29           0.933735           0.912387           0.915408
# 26           0.927711           0.915408           0.912387
# 14           0.930723           0.915408           0.912387
# 21           0.933735           0.918429           0.912387
# 24           0.939759           0.915408           0.915408
# 12           0.939759           0.912387           0.915408
# 19           0.924699           0.918429           0.912387
# 27           0.930723           0.912387           0.912387
# 16           0.933735           0.912387           0.915408
# 23           0.936747           0.918429           0.912387
# 22           0.924699           0.915408           0.909366
# 43           0.927711           0.915408           0.909366
# 31           0.930723           0.915408           0.912387
# 46           0.924699           0.909366           0.906344
# 28           0.930723           0.909366           0.912387
# 20           0.927711           0.915408           0.912387
# 2            0.927711           0.924471           0.912387
# 34           0.936747           0.918429           0.909366
# 0            0.927711           0.921450           0.912387
# 18           0.921687           0.915408           0.909366
# 35           0.936747           0.927492           0.900302
# 1            0.924699           0.921450           0.912387
# 3            0.924699           0.924471           0.912387
# 4            0.924699           0.921450           0.909366
# 5            0.927711           0.924471           0.909366
# 30           0.933735           0.909366           0.906344
# 47           0.915663           0.918429           0.903323
# 38           0.930723           0.927492           0.912387
# 32           0.915663           0.918429           0.912387
# 33           0.933735           0.930514           0.903323
# 40           0.924699           0.921450           0.906344
# 36           0.930723           0.927492           0.915408
# 42           0.924699           0.879154           0.885196
# 41           0.915663           0.918429           0.906344
# 44           0.924699           0.879154           0.912387
# 45           0.918675           0.915408           0.903323
# 39           0.915663           0.921450           0.900302
# 37           0.927711           0.921450           0.915408
# 7            0.882530           0.918429           0.854985
# 6            0.864458           0.900302           0.867069
# 10           0.876506           0.888218           0.858006
# 8            0.876506           0.891239           0.842900
# 9            0.873494           0.870091           0.851964
# 11           0.873494           0.861027           0.851964
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 25           0.909366         0.920933        0.009296                1
# 13           0.909366         0.920933        0.008262                1
# 17           0.918429         0.918522        0.007915                3
# 15           0.915408         0.917918        0.008014                4
# 29           0.912387         0.917313        0.008290                5
# 26           0.927492         0.916720        0.010170                6
# 14           0.924471         0.916718        0.010358                7
# 21           0.918429         0.916716        0.010714                8
# 24           0.915408         0.916715        0.013431                9
# 12           0.915408         0.916713        0.012750               10
# 19           0.915408         0.916112        0.005203               11
# 27           0.918429         0.916110        0.008205               12
# 16           0.915408         0.916110        0.009815               12
# 23           0.915408         0.915510        0.013472               14
# 22           0.918429         0.914303        0.007279               15
# 43           0.924471         0.913704        0.012837               16
# 31           0.915408         0.913701        0.011515               17
# 46           0.921450         0.913697        0.007797               18
# 28           0.912387         0.913695        0.009097               19
# 20           0.915408         0.913098        0.010655               20
# 2            0.912387         0.912500        0.014842               21
# 34           0.906344         0.912490        0.014893               22
# 0            0.909366         0.911291        0.014427               23
# 18           0.918429         0.911291        0.010665               23
# 35           0.903323         0.911284        0.017954               25
# 1            0.909366         0.910689        0.013777               26
# 3            0.909366         0.910088        0.016497               27
# 4            0.912387         0.910086        0.014885               28
# 5            0.909366         0.909484        0.018135               29
# 30           0.921450         0.909480        0.019124               30
# 47           0.921450         0.908279        0.014273               31
# 38           0.900302         0.908277        0.021827               32
# 32           0.906344         0.907071        0.012914               33
# 33           0.885196         0.905252        0.023933               34
# 40           0.888218         0.902841        0.019552               35
# 36           0.873112         0.902239        0.027922               36
# 42           0.924471         0.900415        0.019964               37
# 41           0.888218         0.899827        0.018084               38
# 44           0.888218         0.899807        0.016529               39
# 45           0.876133         0.899214        0.017140               40
# 39           0.891239         0.898020        0.021209               41
# 37           0.864048         0.896808        0.030640               42
# 7            0.885196         0.875096        0.028638               43
# 6            0.824773         0.853971        0.031428               44
# 10           0.833837         0.852759        0.029257               45
# 8            0.845921         0.852759        0.029194               45
# 9            0.839879         0.850941        0.020007               47
# 11           0.854985         0.849740        0.022500               48

# %%
print(grid0.best_params_)
# Out:
# {'clf': LogisticRegression(C=10, max_iter=10000, penalty='l1', solver='liblinear'), 'reduce_dim': TruncatedSVD(n_components=5, random_state=42), 'vect': CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english')}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import TruncatedSVD, NMF

# used to cache results
from tempfile import mkdtemp
from shutil import rmtree
import joblib
from joblib import Memory

# print(__doc__)
location = mkdtemp()
memory = Memory(location=location, verbose=10)

pipeline1 = Pipeline([
    ('vect', vectorizer_df3_lemma),
    ('tfidf', TfidfTransformer()),
    ('reduce_dim', TruncatedSVD(n_components=50, random_state=42)),
    ('clf', SVC(kernel='linear', C=1)),
],
memory=memory
)

param_grid1 = [
    {
        'vect': [vectorizer_df3_stem, 
                 vectorizer_df5_stem,
                 vectorizer_df3_lemma, 
                 vectorizer_df3_nolemma, 
                 vectorizer_df5_lemma, 
                 vectorizer_df5_nolemma],
        'reduce_dim': [TruncatedSVD(n_components=50, random_state=42),
                       NMF(n_components=50, init='random', random_state=42, max_iter=10000)],
        'clf': [SVC(kernel='linear', C=1.0,max_iter=10000), 
                LogisticRegression(penalty='l1', C=10,max_iter=10000, solver='liblinear'), 
                LogisticRegression(penalty='l2', C=100,max_iter=10000, solver = 'liblinear'),
                GaussianNB()]
    }
]
grid1 = GridSearchCV(pipeline1, cv=5, n_jobs=1, param_grid=param_grid1, scoring='accuracy')
grid1.fit(train['full_text'], y_train_encoded.astype(str).astype(int))
rmtree(location)
# Out:
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 7.9s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8048 sparse matrix of type '<class 'numpy.int64'>'
# 	with 248638 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1325x8048 sparse matrix of type '<class 'numpy.float64'>'
# 	with 248638 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8021 sparse matrix of type '<class 'numpy.int64'>'
# 	with 251704 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1325x8021 sparse matrix of type '<class 'numpy.float64'>'
# 	with 251704 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8024 sparse matrix of type '<class 'numpy.int64'>'
# 	with 249406 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x8024 sparse matrix of type '<class 'numpy.float64'>'
# 	with 249406 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8044 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250212 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x8044 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250212 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8158 sparse matrix of type '<class 'numpy.int64'>'
# 	with 251640 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x8158 sparse matrix of type '<class 'numpy.float64'>'
# 	with 251640 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.0s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x5641 sparse matrix of type '<class 'numpy.int64'>'
# 	with 240525 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1325x5641 sparse matrix of type '<class 'numpy.float64'>'
# 	with 240525 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.3s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x5667 sparse matrix of type '<class 'numpy.int64'>'
# 	with 243767 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1325x5667 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243767 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x5661 sparse matrix of type '<class 'numpy.int64'>'
# 	with 241433 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x5661 sparse matrix of type '<class 'numpy.float64'>'
# 	with 241433 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x5669 sparse matrix of type '<class 'numpy.int64'>'
# 	with 242206 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x5669 sparse matrix of type '<class 'numpy.float64'>'
# 	with 242206 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x5724 sparse matrix of type '<class 'numpy.int64'>'
# 	with 243453 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x5724 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243453 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.2s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8984 sparse matrix of type '<class 'numpy.int64'>'
# 	with 243688 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1325x8984 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243688 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.8s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8977 sparse matrix of type '<class 'numpy.int64'>'
# 	with 246701 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1325x8977 sparse matrix of type '<class 'numpy.float64'>'
# 	with 246701 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.5s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8944 sparse matrix of type '<class 'numpy.int64'>'
# 	with 244378 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x8944 sparse matrix of type '<class 'numpy.float64'>'
# 	with 244378 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.8s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8995 sparse matrix of type '<class 'numpy.int64'>'
# 	with 245156 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x8995 sparse matrix of type '<class 'numpy.float64'>'
# 	with 245156 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.7s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x9101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 246531 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x9101 sparse matrix of type '<class 'numpy.float64'>'
# 	with 246531 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x11274 sparse matrix of type '<class 'numpy.int64'>'
# 	with 259228 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1325x11274 sparse matrix of type '<class 'numpy.float64'>'
# 	with 259228 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x11323 sparse matrix of type '<class 'numpy.int64'>'
# 	with 262808 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1325x11323 sparse matrix of type '<class 'numpy.float64'>'
# 	with 262808 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x11269 sparse matrix of type '<class 'numpy.int64'>'
# 	with 260430 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x11269 sparse matrix of type '<class 'numpy.float64'>'
# 	with 260430 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x11332 sparse matrix of type '<class 'numpy.int64'>'
# 	with 261451 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=50, random_state=42), <1326x11332 sparse matrix of type '<class 'numpy.float64'>'
# 	with 261451 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x11463 sparse matrix of type '<class 'numpy.int64'>'
# 	with 262638 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# ...
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/5835e88d99271b17750b112d8a9fa44b
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/68bd60abd5e7fd4c73cf9fb342888199
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/9ee379502f029d2fefdb99e14910de9a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/7c60413492fdf69327e247f81f61b575
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/9d75e26a8ac8b5414e7e9b76bd9c4d28
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/e3c0584d2d0f892838dc929cfec82f08
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/ed3ddd5b866f10d58296c2606bc3bc4d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/90995e5f3922d61beb98b33025a101fc
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/6cc2a2580e287ad55f2b83364f9f293c
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/ab3e333e8ee27416cd71046811f3bf15
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/92da76a90960598bff46e14c10126f1c
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/5c5b2e45bc946220c27489515d5f544d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/870a628abb23ae2b88f98209cef413ff
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/7bca725c07d604d9ad6f5cf0d761c026
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/b345c780e7f97b40cb2223b19beadb93
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/c9c26a45241d883e807cbadef38998ed
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/b8d6c5ef8e5c3ccafaf840b119b7122d
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/9259240f2a8f7e078986239baa62868a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/1b77e7f49e4eace2d0bf7342e9e386cb
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/e98f9c10b170c4650f90b356108185e4
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/197ee628d132eeb011eec78130a00fd9
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/e4fef16552ad1329fe6ed2975090ed3c
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/f446de286d4e7f5a7fd2c73cdba0bc50
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/e3da0403613e0f14fdb7795c8032a3ca
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/aabc06a33e45761ba8eb0cb48ab76a8d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/9a99d4cecb18614fca7d7b2703002d87
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/78bc1ed517a1a5e4701434be6e4bb5ce
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/94b6c2f3ea4bbe6d2a195a83e1a378ca
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/81d9fe590b58ab8fe1439b3e1a9a6ca0
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/7059a84516137dea0e83191d1e786140
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/e668ea2d804ee68002256a799bec060e
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/853fd1756d56f24955fb21712de048ec
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/cf76d826d382c33eea6803df5b814985
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/5beace8ad3492c3414fb54df0c584506
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/794eb5a0ae91647e42e711846b4c1656
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/8cca71ba4df6124937165ead3bf265b9
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/827ec19bc30ae18c0d9783b003f38a88
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/3d4c0f557ee5ca2eb8a235646d3ea992
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/36cd7d6eb6da591bd728b95fb7ad6507
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/5d6074ee40077aece974b43fcf043c12
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/1c25feb28a618241d6519188e590d52b
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/e3dfc4442288e845bb394e066d794e2a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/a6d075e1213f7081d06c01a9ccfae0ed
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/3f9ed141564fd7cfa2d7b2ad14a2e60b
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/af121261c6ee7d5defb3771ee1fd37e2
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/0cf475224e01536b8e75f1312c439705
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/5e2d122fd6be5930aa4f850278d6ec75
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/7c4de9c5ddc5407821fc0ee8bec27952
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpol1xiv2x/joblib/sklearn/pipeline/_fit_transform_one/a09d547df3a2017c99466a3839d250fa
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1657, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1657, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 10.1s, 0.2min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1657x6386 sparse matrix of type '<class 'numpy.int64'>'
# 	with 306043 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1657, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(NMF(init='random', max_iter=10000, n_components=50, random_state=42), <1657x6386 sparse matrix of type '<class 'numpy.float64'>'
# 	with 306043 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1657, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 4.0s, 0.1min

# %%
    
print(grid1.best_params_)
# Out:
# {'clf': GaussianNB(), 'reduce_dim': NMF(init='random', max_iter=10000, n_components=50, random_state=42), 'vect': CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english')}

# %%
gg1 = pd.DataFrame(grid1.cv_results_)

# %%
gg2 = gg1.sort_values(by='mean_test_score',ascending=False)
gg2
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 43       0.079497      0.003423         2.044578        0.100321
# 44       0.089244      0.002240         4.680717        0.213878
# 47       0.093858      0.000992         0.139942        0.006422
# 45       0.100483      0.005163         0.140445        0.005268
# 46       0.085876      0.001528         4.673411        0.211533
# 16       0.097311      0.001911         4.633917        0.207116
# 15       0.112727      0.003694         0.089845        0.004033
# 20       0.092085      0.002162         4.683023        0.215639
# 13       0.090981      0.003367         2.005989        0.096134
# 26       0.095378      0.002703         4.638506        0.208964
# 14       0.100155      0.002120         4.630372        0.207802
# 25       0.085020      0.000569         2.004384        0.095309
# 19       0.081006      0.001318         2.044679        0.095741
# 28       0.092581      0.001500         4.636017        0.208064
# 12       0.092449      0.003310         2.008460        0.096573
# 22       0.090023      0.002619         4.679500        0.211881
# 17       0.106749      0.002765         0.089562        0.003780
# 24       0.088619      0.001625         2.004394        0.093306
# 42       0.080224      0.002294         2.050888        0.093010
# 29       0.103029      0.002340         0.091244        0.004618
# 27       0.106743      0.001242         0.091128        0.005671
# 34       0.088014      0.000784         4.671150        0.210648
# 21       0.103036      0.003270         0.141587        0.004484
# 31       0.080164      0.000869         2.047689        0.098954
# 32       0.090707      0.000603         4.676783        0.211557
# 23       0.098283      0.000699         0.139479        0.008259
# 1        8.475605      0.089804         2.008426        0.094392
# 0        8.510930      0.098518         2.014698        0.098020
# 2       18.949187      0.197572         4.649848        0.199544
# 4       18.917747      0.221599         4.653192        0.207357
# 30       0.083346      0.000853         2.053339        0.093398
# 18       0.086162      0.002619         2.049678        0.096988
# 35       0.097361      0.001376         0.140680        0.002612
# 5        0.807732      0.010911         0.093596        0.003735
# 3        0.876671      0.009467         0.093913        0.003642
# 33       0.101329      0.001123         0.142213        0.006266
# 37       0.075643      0.000936         2.000173        0.094348
# 36       0.078510      0.001517         2.002718        0.093906
# 39       0.095943      0.001376         0.085833        0.003509
# 7        4.892966      1.993542         2.056051        0.094612
# 38       0.086177      0.000682         4.628932        0.212658
# 40       0.080679      0.000449         4.624721        0.211806
# 8        5.335128      1.105848         4.705481        0.210425
# 11       6.163162      2.624693         0.144179        0.006832
# 10       4.518115      1.211080         4.690413        0.217641
# 41       0.092008      0.001108         0.084942        0.003727
# 6        6.961966      4.449876         2.059934        0.096008
# 9        7.317833      0.938497         0.150646        0.010080
#
#                                             param_clf  \
# 43                                       GaussianNB()
# 44                                       GaussianNB()
# 47                                       GaussianNB()
# 45                                       GaussianNB()
# 46                                       GaussianNB()
# 16  LogisticRegression(C=10, max_iter=10000, penal...
# 15  LogisticRegression(C=10, max_iter=10000, penal...
# 20  LogisticRegression(C=10, max_iter=10000, penal...
# 13  LogisticRegression(C=10, max_iter=10000, penal...
# 26  LogisticRegression(C=100, max_iter=10000, solv...
# 14  LogisticRegression(C=10, max_iter=10000, penal...
# 25  LogisticRegression(C=100, max_iter=10000, solv...
# 19  LogisticRegression(C=10, max_iter=10000, penal...
# 28  LogisticRegression(C=100, max_iter=10000, solv...
# 12  LogisticRegression(C=10, max_iter=10000, penal...
# 22  LogisticRegression(C=10, max_iter=10000, penal...
# 17  LogisticRegression(C=10, max_iter=10000, penal...
# 24  LogisticRegression(C=100, max_iter=10000, solv...
# 42                                       GaussianNB()
# 29  LogisticRegression(C=100, max_iter=10000, solv...
# 27  LogisticRegression(C=100, max_iter=10000, solv...
# 34  LogisticRegression(C=100, max_iter=10000, solv...
# 21  LogisticRegression(C=10, max_iter=10000, penal...
# 31  LogisticRegression(C=100, max_iter=10000, solv...
# 32  LogisticRegression(C=100, max_iter=10000, solv...
# 23  LogisticRegression(C=10, max_iter=10000, penal...
# 1                SVC(kernel='linear', max_iter=10000)
# 0                SVC(kernel='linear', max_iter=10000)
# 2                SVC(kernel='linear', max_iter=10000)
# 4                SVC(kernel='linear', max_iter=10000)
# 30  LogisticRegression(C=100, max_iter=10000, solv...
# 18  LogisticRegression(C=10, max_iter=10000, penal...
# 35  LogisticRegression(C=100, max_iter=10000, solv...
# 5                SVC(kernel='linear', max_iter=10000)
# 3                SVC(kernel='linear', max_iter=10000)
# 33  LogisticRegression(C=100, max_iter=10000, solv...
# 37                                       GaussianNB()
# 36                                       GaussianNB()
# 39                                       GaussianNB()
# 7                SVC(kernel='linear', max_iter=10000)
# 38                                       GaussianNB()
# 40                                       GaussianNB()
# 8                SVC(kernel='linear', max_iter=10000)
# 11               SVC(kernel='linear', max_iter=10000)
# 10               SVC(kernel='linear', max_iter=10000)
# 41                                       GaussianNB()
# 6                SVC(kernel='linear', max_iter=10000)
# 9                SVC(kernel='linear', max_iter=10000)
#
#                                      param_reduce_dim  \
# 43  NMF(init='random', max_iter=10000, n_component...
# 44  NMF(init='random', max_iter=10000, n_component...
# 47  NMF(init='random', max_iter=10000, n_component...
# 45  NMF(init='random', max_iter=10000, n_component...
# 46  NMF(init='random', max_iter=10000, n_component...
# 16     TruncatedSVD(n_components=50, random_state=42)
# 15     TruncatedSVD(n_components=50, random_state=42)
# 20  NMF(init='random', max_iter=10000, n_component...
# 13     TruncatedSVD(n_components=50, random_state=42)
# 26     TruncatedSVD(n_components=50, random_state=42)
# 14     TruncatedSVD(n_components=50, random_state=42)
# 25     TruncatedSVD(n_components=50, random_state=42)
# 19  NMF(init='random', max_iter=10000, n_component...
# 28     TruncatedSVD(n_components=50, random_state=42)
# 12     TruncatedSVD(n_components=50, random_state=42)
# 22  NMF(init='random', max_iter=10000, n_component...
# 17     TruncatedSVD(n_components=50, random_state=42)
# 24     TruncatedSVD(n_components=50, random_state=42)
# 42  NMF(init='random', max_iter=10000, n_component...
# 29     TruncatedSVD(n_components=50, random_state=42)
# 27     TruncatedSVD(n_components=50, random_state=42)
# 34  NMF(init='random', max_iter=10000, n_component...
# 21  NMF(init='random', max_iter=10000, n_component...
# 31  NMF(init='random', max_iter=10000, n_component...
# 32  NMF(init='random', max_iter=10000, n_component...
# 23  NMF(init='random', max_iter=10000, n_component...
# 1      TruncatedSVD(n_components=50, random_state=42)
# 0      TruncatedSVD(n_components=50, random_state=42)
# 2      TruncatedSVD(n_components=50, random_state=42)
# 4      TruncatedSVD(n_components=50, random_state=42)
# 30  NMF(init='random', max_iter=10000, n_component...
# 18  NMF(init='random', max_iter=10000, n_component...
# 35  NMF(init='random', max_iter=10000, n_component...
# 5      TruncatedSVD(n_components=50, random_state=42)
# 3      TruncatedSVD(n_components=50, random_state=42)
# 33  NMF(init='random', max_iter=10000, n_component...
# 37     TruncatedSVD(n_components=50, random_state=42)
# 36     TruncatedSVD(n_components=50, random_state=42)
# 39     TruncatedSVD(n_components=50, random_state=42)
# 7   NMF(init='random', max_iter=10000, n_component...
# 38     TruncatedSVD(n_components=50, random_state=42)
# 40     TruncatedSVD(n_components=50, random_state=42)
# 8   NMF(init='random', max_iter=10000, n_component...
# 11  NMF(init='random', max_iter=10000, n_component...
# 10  NMF(init='random', max_iter=10000, n_component...
# 41     TruncatedSVD(n_components=50, random_state=42)
# 6   NMF(init='random', max_iter=10000, n_component...
# 9   NMF(init='random', max_iter=10000, n_component...
#
#                                            param_vect  \
# 43  CountVectorizer(analyzer=<function stemmed at ...
# 44  CountVectorizer(analyzer=<function lemma at 0x...
# 47  CountVectorizer(analyzer=<function nolemma at ...
# 45  CountVectorizer(analyzer=<function nolemma at ...
# 46  CountVectorizer(analyzer=<function lemma at 0x...
# 16  CountVectorizer(analyzer=<function lemma at 0x...
# 15  CountVectorizer(analyzer=<function nolemma at ...
# 20  CountVectorizer(analyzer=<function lemma at 0x...
# 13  CountVectorizer(analyzer=<function stemmed at ...
# 26  CountVectorizer(analyzer=<function lemma at 0x...
# 14  CountVectorizer(analyzer=<function lemma at 0x...
# 25  CountVectorizer(analyzer=<function stemmed at ...
# 19  CountVectorizer(analyzer=<function stemmed at ...
# 28  CountVectorizer(analyzer=<function lemma at 0x...
# 12  CountVectorizer(analyzer=<function stemmed at ...
# 22  CountVectorizer(analyzer=<function lemma at 0x...
# 17  CountVectorizer(analyzer=<function nolemma at ...
# 24  CountVectorizer(analyzer=<function stemmed at ...
# 42  CountVectorizer(analyzer=<function stemmed at ...
# 29  CountVectorizer(analyzer=<function nolemma at ...
# 27  CountVectorizer(analyzer=<function nolemma at ...
# 34  CountVectorizer(analyzer=<function lemma at 0x...
# 21  CountVectorizer(analyzer=<function nolemma at ...
# 31  CountVectorizer(analyzer=<function stemmed at ...
# 32  CountVectorizer(analyzer=<function lemma at 0x...
# 23  CountVectorizer(analyzer=<function nolemma at ...
# 1   CountVectorizer(analyzer=<function stemmed at ...
# 0   CountVectorizer(analyzer=<function stemmed at ...
# 2   CountVectorizer(analyzer=<function lemma at 0x...
# 4   CountVectorizer(analyzer=<function lemma at 0x...
# 30  CountVectorizer(analyzer=<function stemmed at ...
# 18  CountVectorizer(analyzer=<function stemmed at ...
# 35  CountVectorizer(analyzer=<function nolemma at ...
# 5   CountVectorizer(analyzer=<function nolemma at ...
# 3   CountVectorizer(analyzer=<function nolemma at ...
# 33  CountVectorizer(analyzer=<function nolemma at ...
# 37  CountVectorizer(analyzer=<function stemmed at ...
# 36  CountVectorizer(analyzer=<function stemmed at ...
# 39  CountVectorizer(analyzer=<function nolemma at ...
# 7   CountVectorizer(analyzer=<function stemmed at ...
# 38  CountVectorizer(analyzer=<function lemma at 0x...
# 40  CountVectorizer(analyzer=<function lemma at 0x...
# 8   CountVectorizer(analyzer=<function lemma at 0x...
# 11  CountVectorizer(analyzer=<function nolemma at ...
# 10  CountVectorizer(analyzer=<function lemma at 0x...
# 41  CountVectorizer(analyzer=<function nolemma at ...
# 6   CountVectorizer(analyzer=<function stemmed at ...
# 9   CountVectorizer(analyzer=<function nolemma at ...
#
#                                                params  split0_test_score  \
# 43  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.960843
# 44  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.954819
# 47  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.951807
# 45  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.948795
# 46  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.951807
# 16  {'clf': LogisticRegression(C=10, max_iter=1000...           0.951807
# 15  {'clf': LogisticRegression(C=10, max_iter=1000...           0.960843
# 20  {'clf': LogisticRegression(C=10, max_iter=1000...           0.951807
# 13  {'clf': LogisticRegression(C=10, max_iter=1000...           0.951807
# 26  {'clf': LogisticRegression(C=100, max_iter=100...           0.957831
# 14  {'clf': LogisticRegression(C=10, max_iter=1000...           0.951807
# 25  {'clf': LogisticRegression(C=100, max_iter=100...           0.948795
# 19  {'clf': LogisticRegression(C=10, max_iter=1000...           0.942771
# 28  {'clf': LogisticRegression(C=100, max_iter=100...           0.954819
# 12  {'clf': LogisticRegression(C=10, max_iter=1000...           0.951807
# 22  {'clf': LogisticRegression(C=10, max_iter=1000...           0.954819
# 17  {'clf': LogisticRegression(C=10, max_iter=1000...           0.957831
# 24  {'clf': LogisticRegression(C=100, max_iter=100...           0.948795
# 42  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.954819
# 29  {'clf': LogisticRegression(C=100, max_iter=100...           0.954819
# 27  {'clf': LogisticRegression(C=100, max_iter=100...           0.948795
# 34  {'clf': LogisticRegression(C=100, max_iter=100...           0.942771
# 21  {'clf': LogisticRegression(C=10, max_iter=1000...           0.942771
# 31  {'clf': LogisticRegression(C=100, max_iter=100...           0.930723
# 32  {'clf': LogisticRegression(C=100, max_iter=100...           0.945783
# 23  {'clf': LogisticRegression(C=10, max_iter=1000...           0.945783
# 1   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.936747
# 0   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.924699
# 2   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.927711
# 4   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.927711
# 30  {'clf': LogisticRegression(C=100, max_iter=100...           0.936747
# 18  {'clf': LogisticRegression(C=10, max_iter=1000...           0.942771
# 35  {'clf': LogisticRegression(C=100, max_iter=100...           0.936747
# 5   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.930723
# 3   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.933735
# 33  {'clf': LogisticRegression(C=100, max_iter=100...           0.927711
# 37  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.918675
# 36  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.894578
# 39  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.918675
# 7   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.894578
# 38  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.900602
# 40  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.906627
# 8   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.894578
# 11  {'clf': SVC(kernel='linear', max_iter=10000), ...           0.888554
# 10  {'clf': SVC(kernel='linear', max_iter=10000), ...           0.879518
# 41  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.921687
# 6   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.831325
# 9   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.888554
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 43           0.972892           0.969789           0.963746
# 44           0.975904           0.963746           0.954683
# 47           0.963855           0.969789           0.954683
# 45           0.966867           0.966767           0.957704
# 46           0.969880           0.966767           0.948640
# 16           0.966867           0.969789           0.951662
# 15           0.966867           0.966767           0.948640
# 20           0.963855           0.960725           0.951662
# 13           0.966867           0.966767           0.954683
# 26           0.963855           0.963746           0.948640
# 14           0.960843           0.963746           0.951662
# 25           0.963855           0.972810           0.948640
# 19           0.972892           0.957704           0.960725
# 28           0.960843           0.963746           0.948640
# 12           0.966867           0.966767           0.951662
# 22           0.966867           0.960725           0.963746
# 17           0.966867           0.963746           0.948640
# 24           0.963855           0.966767           0.948640
# 42           0.960843           0.957704           0.948640
# 29           0.963855           0.966767           0.945619
# 27           0.966867           0.963746           0.948640
# 34           0.969880           0.957704           0.951662
# 21           0.954819           0.960725           0.945619
# 31           0.963855           0.951662           0.957704
# 32           0.963855           0.954683           0.942598
# 23           0.951807           0.963746           0.948640
# 1            0.954819           0.960725           0.942598
# 0            0.957831           0.963746           0.942598
# 2            0.954819           0.960725           0.948640
# 4            0.954819           0.960725           0.945619
# 30           0.957831           0.951662           0.945619
# 18           0.957831           0.954683           0.939577
# 35           0.948795           0.957704           0.936556
# 5            0.954819           0.951662           0.942598
# 3            0.951807           0.954683           0.939577
# 33           0.948795           0.954683           0.942598
# 37           0.939759           0.942598           0.936556
# 36           0.948795           0.951662           0.936556
# 39           0.954819           0.942598           0.921450
# 7            0.936747           0.945619           0.939577
# 38           0.945783           0.936556           0.933535
# 40           0.939759           0.930514           0.936556
# 8            0.942771           0.918429           0.936556
# 11           0.936747           0.906344           0.939577
# 10           0.909639           0.927492           0.936556
# 41           0.945783           0.927492           0.918429
# 6            0.939759           0.942598           0.939577
# 9            0.948795           0.915408           0.848943
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 43           0.948640         0.963182        0.008428                1
# 44           0.963746         0.962580        0.007782                2
# 47           0.966767         0.961380        0.006962                3
# 45           0.960725         0.960172        0.006696                4
# 46           0.963746         0.960168        0.008408                5
# 16           0.957704         0.959566        0.007536                6
# 15           0.951662         0.958956        0.007573                7
# 20           0.963746         0.958359        0.005525                8
# 13           0.951662         0.958357        0.006991                9
# 26           0.957704         0.958355        0.005557               10
# 14           0.960725         0.957757        0.005035               11
# 25           0.954683         0.957757        0.009345               11
# 19           0.954683         0.957755        0.009715               13
# 28           0.960725         0.957755        0.005403               14
# 12           0.951662         0.957753        0.007401               15
# 22           0.942598         0.957751        0.008557               16
# 17           0.951662         0.957749        0.006916               17
# 24           0.954683         0.956548        0.007536               18
# 42           0.957704         0.955942        0.004118               19
# 29           0.948640         0.955940        0.008258               20
# 27           0.948640         0.955338        0.008199               21
# 34           0.951662         0.954736        0.008946               22
# 21           0.960725         0.952932        0.007507               23
# 31           0.957704         0.952330        0.011471               24
# 32           0.954683         0.952320        0.007503               25
# 23           0.945619         0.951119        0.006705               26
# 1            0.957704         0.950519        0.009238               27
# 0            0.960725         0.949920        0.014562               28
# 2            0.957704         0.949920        0.011800               28
# 4            0.960725         0.949920        0.012404               28
# 30           0.954683         0.949308        0.007463               31
# 18           0.951662         0.949305        0.006993               32
# 35           0.954683         0.946897        0.008843               33
# 5            0.954683         0.946897        0.009232               33
# 3            0.954683         0.946897        0.008627               33
# 33           0.954683         0.945694        0.010042               36
# 37           0.942598         0.936037        0.008963               37
# 36           0.930514         0.932421        0.020451               38
# 39           0.918429         0.931194        0.014851               39
# 7            0.936556         0.930616        0.018314               40
# 38           0.936556         0.930606        0.015556               41
# 40           0.930514         0.928794        0.011643               42
# 8            0.924471         0.923361        0.016762               43
# 11           0.918429         0.917930        0.019079               44
# 10           0.933535         0.917348        0.021092               45
# 41           0.870091         0.916696        0.025150               46
# 6            0.900302         0.910712        0.042671               47
# 9            0.903323         0.901005        0.032748               48

# %%
gg2.shape

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import TruncatedSVD, NMF

# used to cache results
from tempfile import mkdtemp
from shutil import rmtree
import joblib
from joblib import Memory

# print(__doc__)
location = mkdtemp()
memory = Memory(location=location, verbose=10)

pipeline2 = Pipeline([
    ('vect', vectorizer_df3_lemma),
    ('tfidf', TfidfTransformer()),
    ('reduce_dim', TruncatedSVD(n_components=50, random_state=42)),
    ('clf', SVC(kernel='linear', C=1)),
],
memory=memory
)

param_grid2 = [
    {
        'vect': [vectorizer_df3_stem, 
                 vectorizer_df5_stem, 
                 vectorizer_df3_lemma, 
                 vectorizer_df3_nolemma, 
                 vectorizer_df5_lemma, 
                 vectorizer_df5_nolemma],
        
        'reduce_dim': [TruncatedSVD(n_components=500, random_state=42), 
                       NMF(n_components=500, init='random', random_state=42, max_iter=10000)],
        
        'clf': [SVC(kernel='linear', C=1.0,max_iter=10000), 
                LogisticRegression(penalty='l1', C=10,max_iter=10000, solver='liblinear'), 
                LogisticRegression(penalty='l2', C=100,max_iter=10000, solver = 'liblinear'),
                GaussianNB()]
    }
]
grid2 = GridSearchCV(pipeline2, cv=5, n_jobs=1, param_grid=param_grid2, scoring='accuracy')
grid2.fit(train['full_text'], y_train_encoded.astype(str).astype(int))
rmtree(location)
# Out:
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 7.9s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8048 sparse matrix of type '<class 'numpy.int64'>'
# 	with 248638 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1325x8048 sparse matrix of type '<class 'numpy.float64'>'
# 	with 248638 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8021 sparse matrix of type '<class 'numpy.int64'>'
# 	with 251704 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1325x8021 sparse matrix of type '<class 'numpy.float64'>'
# 	with 251704 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.0s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8024 sparse matrix of type '<class 'numpy.int64'>'
# 	with 249406 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x8024 sparse matrix of type '<class 'numpy.float64'>'
# 	with 249406 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8044 sparse matrix of type '<class 'numpy.int64'>'
# 	with 250212 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x8044 sparse matrix of type '<class 'numpy.float64'>'
# 	with 250212 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.1s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.2s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8158 sparse matrix of type '<class 'numpy.int64'>'
# 	with 251640 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x8158 sparse matrix of type '<class 'numpy.float64'>'
# 	with 251640 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.2s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.0s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x5641 sparse matrix of type '<class 'numpy.int64'>'
# 	with 240525 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1325x5641 sparse matrix of type '<class 'numpy.float64'>'
# 	with 240525 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 1.7s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x5667 sparse matrix of type '<class 'numpy.int64'>'
# 	with 243767 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1325x5667 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243767 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x5661 sparse matrix of type '<class 'numpy.int64'>'
# 	with 241433 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x5661 sparse matrix of type '<class 'numpy.float64'>'
# 	with 241433 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 1.7s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x5669 sparse matrix of type '<class 'numpy.int64'>'
# 	with 242206 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x5669 sparse matrix of type '<class 'numpy.float64'>'
# 	with 242206 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 1.7s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function stemmed at 0x7f8461748700>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 8.1s, 0.1min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x5724 sparse matrix of type '<class 'numpy.int64'>'
# 	with 243453 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x5724 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243453 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 1.8s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.3s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8984 sparse matrix of type '<class 'numpy.int64'>'
# 	with 243688 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1325x8984 sparse matrix of type '<class 'numpy.float64'>'
# 	with 243688 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.7s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x8977 sparse matrix of type '<class 'numpy.int64'>'
# 	with 246701 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1325x8977 sparse matrix of type '<class 'numpy.float64'>'
# 	with 246701 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.5s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8944 sparse matrix of type '<class 'numpy.int64'>'
# 	with 244378 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x8944 sparse matrix of type '<class 'numpy.float64'>'
# 	with 244378 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.7s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x8995 sparse matrix of type '<class 'numpy.int64'>'
# 	with 245156 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x8995 sparse matrix of type '<class 'numpy.float64'>'
# 	with 245156 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.3s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function lemma at 0x7f8467a87160>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# _______________________________________________fit_transform_one - 18.8s, 0.3min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x9101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 246531 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x9101 sparse matrix of type '<class 'numpy.float64'>'
# 	with 246531 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.4s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 186     (CNN) Indian police have arrested three Kashmi...
# 212     India's Mayank Agarwal , left, talks with Axar...
# 495     Game recap\n\nOffensive MVP\n\nTanner Morgan, ...
# 190     Kashmiri students assaulted and bowler Mohamme...
# 890     Lincoln High School’s marching band was named ...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.4s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x11274 sparse matrix of type '<class 'numpy.int64'>'
# 	with 259228 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1325x11274 sparse matrix of type '<class 'numpy.float64'>'
# 	with 259228 stored elements in Compressed Sparse Row format>,
# 186     0
# 212     0
# 495     0
# 190     0
# 890     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.7s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1325, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1325x11323 sparse matrix of type '<class 'numpy.int64'>'
# 	with 262808 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1325x11323 sparse matrix of type '<class 'numpy.float64'>'
# 	with 262808 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1325, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.8s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x11269 sparse matrix of type '<class 'numpy.int64'>'
# 	with 260430 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x11269 sparse matrix of type '<class 'numpy.float64'>'
# 	with 260430 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.7s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x11332 sparse matrix of type '<class 'numpy.int64'>'
# 	with 261451 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1326x11332 sparse matrix of type '<class 'numpy.float64'>'
# 	with 261451 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.7s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=3,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 852     The team behind the Stockfish chess engine has...
# 473     Sports Ramapo Icon Drew Gibbs Remembered By NJ...
# 942     Articles Sorry, there are no recent results fo...
# 493     LSU wide receiver Trey Palmer (33) heads upfie...
# 261     Texas finally halted its losing streak at six ...
# Name: full_text, Length: 1326, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.5s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1326x11463 sparse matrix of type '<class 'numpy.int64'>'
# 	with 262638 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 852     0
# 473     0
# 942     0
# 493     0
# 261     0
# Name: root_label, Length: 1326, dtype: int64,
# ...
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/2eafe10142afd47a464f6d0c45582370
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/68bd60abd5e7fd4c73cf9fb342888199
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/9ee379502f029d2fefdb99e14910de9a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/d463cf7e69767a4307bb91a67fba37de
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/9d75e26a8ac8b5414e7e9b76bd9c4d28
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/e3c0584d2d0f892838dc929cfec82f08
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/d362860215d237a9bfc2ed7bd5f4864d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/90995e5f3922d61beb98b33025a101fc
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/6cc2a2580e287ad55f2b83364f9f293c
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/14a7089052723c63a17735b19f6fafc9
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/92da76a90960598bff46e14c10126f1c
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/5c5b2e45bc946220c27489515d5f544d
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/f03fbe0ea98e26f6cd884f62fb763887
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/7bca725c07d604d9ad6f5cf0d761c026
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/b345c780e7f97b40cb2223b19beadb93
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/77233d15e59ea98ca66b2c61cb1cfe97
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/b8d6c5ef8e5c3ccafaf840b119b7122d
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/9259240f2a8f7e078986239baa62868a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/6bbe40d0c0aa6e4d67cea5f25e8bd554
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/e98f9c10b170c4650f90b356108185e4
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/197ee628d132eeb011eec78130a00fd9
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/cff347c78c12be459dfc7ecf98b35c32
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/f446de286d4e7f5a7fd2c73cdba0bc50
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/e3da0403613e0f14fdb7795c8032a3ca
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/7ef3a877ad920fea75d32173a959cc25
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/9a99d4cecb18614fca7d7b2703002d87
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/78bc1ed517a1a5e4701434be6e4bb5ce
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/ec1bbb20dff562129138b6779c255e61
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/81d9fe590b58ab8fe1439b3e1a9a6ca0
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/7059a84516137dea0e83191d1e786140
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/b7022b6084aaa9cad67bf3b9529ae3c0
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/853fd1756d56f24955fb21712de048ec
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/cf76d826d382c33eea6803df5b814985
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/0f22e65bd553be5c80b183691d4c36df
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/794eb5a0ae91647e42e711846b4c1656
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/8cca71ba4df6124937165ead3bf265b9
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/341ee1b7340b833eb5b03fb28a62c8d7
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/3d4c0f557ee5ca2eb8a235646d3ea992
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/36cd7d6eb6da591bd728b95fb7ad6507
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/ca4be171bb01bbf1884c99830e6a0b36
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/1c25feb28a618241d6519188e590d52b
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/e3dfc4442288e845bb394e066d794e2a
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/da82d45beb3009228c5374c4c6d3af96
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/3f9ed141564fd7cfa2d7b2ad14a2e60b
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/af121261c6ee7d5defb3771ee1fd37e2
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/389ab0d94afb14bcf7564c88032bd821
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.0s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/5e2d122fd6be5930aa4f850278d6ec75
# ___________________________________fit_transform_one cache loaded - 0.1s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/7c4de9c5ddc5407821fc0ee8bec27952
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# [Memory]0.1s, 0.0min    : Loading _fit_transform_one from /var/folders/nd/y54n6bcj22s8tqwfp8nvqjkr0000gn/T/tmpeke12o1q/joblib/sklearn/pipeline/_fit_transform_one/7fcb362d06d1f208ca383cb0ae66de51
# ___________________________________fit_transform_one cache loaded - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=5,
#                 stop_words='english'),
# 1626    Coal mining authorities say that one miner is ...
# 23      © Nikhil Naz Virat Kohli to play ODIs in South...
# 880     Play Magnus Group to Bring Chess NFTs to Marke...
# 1040    This holiday season, The Save Movement is urgi...
# 950     Queens, NY – James Todd Smith — better known a...
#                               ...
# 303     Seacrest out, Ted Lasso in. Ryan Seacrest and ...
# 1012    Citrusw00d Productions unveils films minted as...
# 267     FILE - Tennessee Titans running back Derrick H...
# 1763    A swarm of earthquakes has been rattling the o...
# 1588    A very strong 5.5 earthquake was just recorded...
# Name: full_text, Length: 1657, dtype: object,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1657, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.6s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TfidfTransformer(), <1657x8829 sparse matrix of type '<class 'numpy.int64'>'
# 	with 316363 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1657, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling sklearn.pipeline._fit_transform_one...
# _fit_transform_one(TruncatedSVD(n_components=500, random_state=42), <1657x8829 sparse matrix of type '<class 'numpy.float64'>'
# 	with 316363 stored elements in Compressed Sparse Row format>,
# 1626    1
# 23      0
# 880     0
# 1040    1
# 950     0
#        ..
# 303     0
# 1012    0
# 267     0
# 1763    1
# 1588    1
# Name: root_label, Length: 1657, dtype: int64,
# None, message_clsname='Pipeline', message=None)
# ________________________________________________fit_transform_one - 2.7s, 0.0min

# %%
gg3 = pd.DataFrame(grid2.cv_results_)

gg4 = gg3.sort_values(by='mean_test_score',ascending=False)

# %%
gg4
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 29       0.184160      0.002962         0.099025        0.003273
# 13       0.148550      0.013074         2.024289        0.093728
# 16       0.159274      0.008236         4.948843        0.189158
# 27       0.195431      0.005214         0.102562        0.004646
# 26       0.179416      0.002615         4.702643        0.207203
# 24       0.174016      0.003785         2.022858        0.095310
# 14       0.179823      0.010905         4.716090        0.232438
# 25       0.168736      0.001078         2.026569        0.094424
# 12       0.157422      0.011054         2.026038        0.099564
# 5        2.863020      0.023643         0.109387        0.003465
# 17       0.166679      0.008072         0.104373        0.004547
# 28       0.176319      0.003029         4.636293        0.214059
# 15       0.192500      0.017985         0.103377        0.003890
# 0       10.513543      0.080293         2.001699        0.094019
# 1       10.242904      0.311957         2.008663        0.097301
# 2       21.220450      0.208785         4.666857        0.199859
# 3        3.540693      0.043143         0.112192        0.003553
# 4       20.848890      0.138404         4.667618        0.212237
# 43       0.089604      0.001967         4.569371        0.164051
# 42       0.093914      0.001908         4.911124        0.127258
# 44       0.100858      0.001185         7.812348        0.148438
# 34       0.119633      0.001927         7.414028        0.245547
# 46       0.095758      0.001094         7.358826        0.262143
# 45       0.114554      0.000500         3.877263        0.462678
# 47       0.106288      0.001410         3.292749        0.315212
# 32       0.122697      0.002836         7.783225        0.162706
# 31       0.114211      0.001874         4.572995        0.169772
# 35       0.130651      0.000992         3.357850        0.318877
# 30       0.116606      0.003043         4.896564        0.152594
# 33       0.136158      0.002170         3.904812        0.486141
# 23       0.118634      0.002828         3.383900        0.281210
# 20       0.114221      0.002382         7.914346        0.191904
# 22       0.105972      0.004429         7.389208        0.243928
# 19       0.102166      0.002092         4.681414        0.192952
# 21       0.125103      0.002219         3.878974        0.473822
# 18       0.105517      0.001661         4.995645        0.265463
# 39       0.111448      0.001077         0.099913        0.003823
# 41       0.103355      0.001746         0.097253        0.003619
# 37       0.087047      0.001226         2.016109        0.100925
# 40       0.091415      0.001799         4.657275        0.199073
# 38       0.098641      0.000539         4.669039        0.222437
# 10     798.953437    120.386693         7.425919        0.289522
# 36       0.093561      0.001665         2.028223        0.097176
# 7      778.061888    300.180345         4.612622        0.162382
# 11    1088.430307    386.041679         3.346610        0.305714
# 9     1711.193559    405.234356         3.903415        0.479724
# 6      889.062769    324.407300         4.909428        0.150791
# 8     1186.260643    251.123951         7.873750        0.153273
#
#                                             param_clf  \
# 29  LogisticRegression(C=100, max_iter=10000, solv...
# 13  LogisticRegression(C=10, max_iter=10000, penal...
# 16  LogisticRegression(C=10, max_iter=10000, penal...
# 27  LogisticRegression(C=100, max_iter=10000, solv...
# 26  LogisticRegression(C=100, max_iter=10000, solv...
# 24  LogisticRegression(C=100, max_iter=10000, solv...
# 14  LogisticRegression(C=10, max_iter=10000, penal...
# 25  LogisticRegression(C=100, max_iter=10000, solv...
# 12  LogisticRegression(C=10, max_iter=10000, penal...
# 5                SVC(kernel='linear', max_iter=10000)
# 17  LogisticRegression(C=10, max_iter=10000, penal...
# 28  LogisticRegression(C=100, max_iter=10000, solv...
# 15  LogisticRegression(C=10, max_iter=10000, penal...
# 0                SVC(kernel='linear', max_iter=10000)
# 1                SVC(kernel='linear', max_iter=10000)
# 2                SVC(kernel='linear', max_iter=10000)
# 3                SVC(kernel='linear', max_iter=10000)
# 4                SVC(kernel='linear', max_iter=10000)
# 43                                       GaussianNB()
# 42                                       GaussianNB()
# 44                                       GaussianNB()
# 34  LogisticRegression(C=100, max_iter=10000, solv...
# 46                                       GaussianNB()
# 45                                       GaussianNB()
# 47                                       GaussianNB()
# 32  LogisticRegression(C=100, max_iter=10000, solv...
# 31  LogisticRegression(C=100, max_iter=10000, solv...
# 35  LogisticRegression(C=100, max_iter=10000, solv...
# 30  LogisticRegression(C=100, max_iter=10000, solv...
# 33  LogisticRegression(C=100, max_iter=10000, solv...
# 23  LogisticRegression(C=10, max_iter=10000, penal...
# 20  LogisticRegression(C=10, max_iter=10000, penal...
# 22  LogisticRegression(C=10, max_iter=10000, penal...
# 19  LogisticRegression(C=10, max_iter=10000, penal...
# 21  LogisticRegression(C=10, max_iter=10000, penal...
# 18  LogisticRegression(C=10, max_iter=10000, penal...
# 39                                       GaussianNB()
# 41                                       GaussianNB()
# 37                                       GaussianNB()
# 40                                       GaussianNB()
# 38                                       GaussianNB()
# 10               SVC(kernel='linear', max_iter=10000)
# 36                                       GaussianNB()
# 7                SVC(kernel='linear', max_iter=10000)
# 11               SVC(kernel='linear', max_iter=10000)
# 9                SVC(kernel='linear', max_iter=10000)
# 6                SVC(kernel='linear', max_iter=10000)
# 8                SVC(kernel='linear', max_iter=10000)
#
#                                      param_reduce_dim  \
# 29    TruncatedSVD(n_components=500, random_state=42)
# 13    TruncatedSVD(n_components=500, random_state=42)
# 16    TruncatedSVD(n_components=500, random_state=42)
# 27    TruncatedSVD(n_components=500, random_state=42)
# 26    TruncatedSVD(n_components=500, random_state=42)
# 24    TruncatedSVD(n_components=500, random_state=42)
# 14    TruncatedSVD(n_components=500, random_state=42)
# 25    TruncatedSVD(n_components=500, random_state=42)
# 12    TruncatedSVD(n_components=500, random_state=42)
# 5     TruncatedSVD(n_components=500, random_state=42)
# 17    TruncatedSVD(n_components=500, random_state=42)
# 28    TruncatedSVD(n_components=500, random_state=42)
# 15    TruncatedSVD(n_components=500, random_state=42)
# 0     TruncatedSVD(n_components=500, random_state=42)
# 1     TruncatedSVD(n_components=500, random_state=42)
# 2     TruncatedSVD(n_components=500, random_state=42)
# 3     TruncatedSVD(n_components=500, random_state=42)
# 4     TruncatedSVD(n_components=500, random_state=42)
# 43  NMF(init='random', max_iter=10000, n_component...
# 42  NMF(init='random', max_iter=10000, n_component...
# 44  NMF(init='random', max_iter=10000, n_component...
# 34  NMF(init='random', max_iter=10000, n_component...
# 46  NMF(init='random', max_iter=10000, n_component...
# 45  NMF(init='random', max_iter=10000, n_component...
# 47  NMF(init='random', max_iter=10000, n_component...
# 32  NMF(init='random', max_iter=10000, n_component...
# 31  NMF(init='random', max_iter=10000, n_component...
# 35  NMF(init='random', max_iter=10000, n_component...
# 30  NMF(init='random', max_iter=10000, n_component...
# 33  NMF(init='random', max_iter=10000, n_component...
# 23  NMF(init='random', max_iter=10000, n_component...
# 20  NMF(init='random', max_iter=10000, n_component...
# 22  NMF(init='random', max_iter=10000, n_component...
# 19  NMF(init='random', max_iter=10000, n_component...
# 21  NMF(init='random', max_iter=10000, n_component...
# 18  NMF(init='random', max_iter=10000, n_component...
# 39    TruncatedSVD(n_components=500, random_state=42)
# 41    TruncatedSVD(n_components=500, random_state=42)
# 37    TruncatedSVD(n_components=500, random_state=42)
# 40    TruncatedSVD(n_components=500, random_state=42)
# 38    TruncatedSVD(n_components=500, random_state=42)
# 10  NMF(init='random', max_iter=10000, n_component...
# 36    TruncatedSVD(n_components=500, random_state=42)
# 7   NMF(init='random', max_iter=10000, n_component...
# 11  NMF(init='random', max_iter=10000, n_component...
# 9   NMF(init='random', max_iter=10000, n_component...
# 6   NMF(init='random', max_iter=10000, n_component...
# 8   NMF(init='random', max_iter=10000, n_component...
#
#                                            param_vect  \
# 29  CountVectorizer(analyzer=<function nolemma at ...
# 13  CountVectorizer(analyzer=<function stemmed at ...
# 16  CountVectorizer(analyzer=<function lemma at 0x...
# 27  CountVectorizer(analyzer=<function nolemma at ...
# 26  CountVectorizer(analyzer=<function lemma at 0x...
# 24  CountVectorizer(analyzer=<function stemmed at ...
# 14  CountVectorizer(analyzer=<function lemma at 0x...
# 25  CountVectorizer(analyzer=<function stemmed at ...
# 12  CountVectorizer(analyzer=<function stemmed at ...
# 5   CountVectorizer(analyzer=<function nolemma at ...
# 17  CountVectorizer(analyzer=<function nolemma at ...
# 28  CountVectorizer(analyzer=<function lemma at 0x...
# 15  CountVectorizer(analyzer=<function nolemma at ...
# 0   CountVectorizer(analyzer=<function stemmed at ...
# 1   CountVectorizer(analyzer=<function stemmed at ...
# 2   CountVectorizer(analyzer=<function lemma at 0x...
# 3   CountVectorizer(analyzer=<function nolemma at ...
# 4   CountVectorizer(analyzer=<function lemma at 0x...
# 43  CountVectorizer(analyzer=<function stemmed at ...
# 42  CountVectorizer(analyzer=<function stemmed at ...
# 44  CountVectorizer(analyzer=<function lemma at 0x...
# 34  CountVectorizer(analyzer=<function lemma at 0x...
# 46  CountVectorizer(analyzer=<function lemma at 0x...
# 45  CountVectorizer(analyzer=<function nolemma at ...
# 47  CountVectorizer(analyzer=<function nolemma at ...
# 32  CountVectorizer(analyzer=<function lemma at 0x...
# 31  CountVectorizer(analyzer=<function stemmed at ...
# 35  CountVectorizer(analyzer=<function nolemma at ...
# 30  CountVectorizer(analyzer=<function stemmed at ...
# 33  CountVectorizer(analyzer=<function nolemma at ...
# 23  CountVectorizer(analyzer=<function nolemma at ...
# 20  CountVectorizer(analyzer=<function lemma at 0x...
# 22  CountVectorizer(analyzer=<function lemma at 0x...
# 19  CountVectorizer(analyzer=<function stemmed at ...
# 21  CountVectorizer(analyzer=<function nolemma at ...
# 18  CountVectorizer(analyzer=<function stemmed at ...
# 39  CountVectorizer(analyzer=<function nolemma at ...
# 41  CountVectorizer(analyzer=<function nolemma at ...
# 37  CountVectorizer(analyzer=<function stemmed at ...
# 40  CountVectorizer(analyzer=<function lemma at 0x...
# 38  CountVectorizer(analyzer=<function lemma at 0x...
# 10  CountVectorizer(analyzer=<function lemma at 0x...
# 36  CountVectorizer(analyzer=<function stemmed at ...
# 7   CountVectorizer(analyzer=<function stemmed at ...
# 11  CountVectorizer(analyzer=<function nolemma at ...
# 9   CountVectorizer(analyzer=<function nolemma at ...
# 6   CountVectorizer(analyzer=<function stemmed at ...
# 8   CountVectorizer(analyzer=<function lemma at 0x...
#
#                                                params  split0_test_score  \
# 29  {'clf': LogisticRegression(C=100, max_iter=100...           0.972892
# 13  {'clf': LogisticRegression(C=10, max_iter=1000...           0.957831
# 16  {'clf': LogisticRegression(C=10, max_iter=1000...           0.960843
# 27  {'clf': LogisticRegression(C=100, max_iter=100...           0.966867
# 26  {'clf': LogisticRegression(C=100, max_iter=100...           0.966867
# 24  {'clf': LogisticRegression(C=100, max_iter=100...           0.963855
# 14  {'clf': LogisticRegression(C=10, max_iter=1000...           0.960843
# 25  {'clf': LogisticRegression(C=100, max_iter=100...           0.966867
# 12  {'clf': LogisticRegression(C=10, max_iter=1000...           0.957831
# 5   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.960843
# 17  {'clf': LogisticRegression(C=10, max_iter=1000...           0.948795
# 28  {'clf': LogisticRegression(C=100, max_iter=100...           0.966867
# 15  {'clf': LogisticRegression(C=10, max_iter=1000...           0.945783
# 0   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.954819
# 1   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.957831
# 2   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.951807
# 3   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.954819
# 4   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.951807
# 43  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.957831
# 42  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.960843
# 44  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.966867
# 34  {'clf': LogisticRegression(C=100, max_iter=100...           0.951807
# 46  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.954819
# 45  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.960843
# 47  {'clf': GaussianNB(), 'reduce_dim': NMF(init='...           0.951807
# 32  {'clf': LogisticRegression(C=100, max_iter=100...           0.942771
# 31  {'clf': LogisticRegression(C=100, max_iter=100...           0.951807
# 35  {'clf': LogisticRegression(C=100, max_iter=100...           0.948795
# 30  {'clf': LogisticRegression(C=100, max_iter=100...           0.933735
# 33  {'clf': LogisticRegression(C=100, max_iter=100...           0.930723
# 23  {'clf': LogisticRegression(C=10, max_iter=1000...           0.945783
# 20  {'clf': LogisticRegression(C=10, max_iter=1000...           0.921687
# 22  {'clf': LogisticRegression(C=10, max_iter=1000...           0.936747
# 19  {'clf': LogisticRegression(C=10, max_iter=1000...           0.939759
# 21  {'clf': LogisticRegression(C=10, max_iter=1000...           0.918675
# 18  {'clf': LogisticRegression(C=10, max_iter=1000...           0.909639
# 39  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.927711
# 41  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.933735
# 37  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.915663
# 40  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.921687
# 38  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.936747
# 10  {'clf': SVC(kernel='linear', max_iter=10000), ...           0.900602
# 36  {'clf': GaussianNB(), 'reduce_dim': TruncatedS...           0.897590
# 7   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.903614
# 11  {'clf': SVC(kernel='linear', max_iter=10000), ...           0.858434
# 9   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.746988
# 6   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.743976
# 8   {'clf': SVC(kernel='linear', max_iter=10000), ...           0.780120
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 29           0.975904           0.978852           0.957704
# 13           0.978916           0.978852           0.966767
# 16           0.981928           0.975831           0.957704
# 27           0.972892           0.975831           0.954683
# 26           0.963855           0.978852           0.960725
# 24           0.960843           0.978852           0.963746
# 14           0.969880           0.978852           0.954683
# 25           0.966867           0.975831           0.957704
# 12           0.975904           0.978852           0.954683
# 5            0.975904           0.969789           0.957704
# 17           0.972892           0.978852           0.957704
# 28           0.966867           0.969789           0.957704
# 15           0.966867           0.975831           0.960725
# 0            0.963855           0.978852           0.963746
# 1            0.969880           0.969789           0.963746
# 2            0.960843           0.975831           0.957704
# 3            0.966867           0.969789           0.954683
# 4            0.963855           0.975831           0.954683
# 43           0.969880           0.960725           0.954683
# 42           0.963855           0.969789           0.948640
# 44           0.960843           0.951662           0.957704
# 34           0.960843           0.957704           0.966767
# 46           0.957831           0.960725           0.954683
# 45           0.960843           0.954683           0.951662
# 47           0.963855           0.957704           0.951662
# 32           0.960843           0.954683           0.951662
# 31           0.954819           0.954683           0.963746
# 35           0.957831           0.963746           0.954683
# 30           0.969880           0.954683           0.954683
# 33           0.957831           0.957704           0.951662
# 23           0.966867           0.960725           0.948640
# 20           0.954819           0.942598           0.960725
# 22           0.942771           0.960725           0.945619
# 19           0.942771           0.951662           0.954683
# 21           0.963855           0.942598           0.957704
# 18           0.960843           0.954683           0.963746
# 39           0.942771           0.951662           0.930514
# 41           0.945783           0.960725           0.936556
# 37           0.921687           0.942598           0.918429
# 40           0.918675           0.927492           0.924471
# 38           0.912651           0.870091           0.894260
# 10           0.918675           0.879154           0.921450
# 36           0.891566           0.867069           0.897281
# 7            0.852410           0.897281           0.918429
# 11           0.888554           0.858006           0.812689
# 9            0.798193           0.806647           0.945619
# 6            0.813253           0.827795           0.851964
# 8            0.804217           0.803625           0.827795
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 29           0.978852         0.972841        0.007884                1
# 13           0.969789         0.970431        0.007943                2
# 16           0.972810         0.969823        0.009155                3
# 27           0.972810         0.968616        0.007551                4
# 26           0.969789         0.968018        0.006202                5
# 24           0.969789         0.967417        0.006415                6
# 14           0.972810         0.967413        0.008617                7
# 25           0.966767         0.966807        0.005732                8
# 12           0.966767         0.966807        0.009543                9
# 5            0.969789         0.966806        0.006618               10
# 17           0.966767         0.965002        0.010706               11
# 28           0.963746         0.964995        0.004116               12
# 15           0.969789         0.963799        0.010238               13
# 0            0.957704         0.963795        0.008299               14
# 1            0.957704         0.963790        0.005397               15
# 2            0.966767         0.962591        0.008197               16
# 3            0.966767         0.962585        0.006488               17
# 4            0.963746         0.961984        0.008429               18
# 43           0.966767         0.961977        0.005610               19
# 42           0.963746         0.961375        0.007000               20
# 44           0.963746         0.960165        0.005226               21
# 34           0.960725         0.959569        0.004868               22
# 46           0.957704         0.957152        0.002239               23
# 45           0.954683         0.956543        0.003681               24
# 47           0.954683         0.955942        0.004533               25
# 32           0.966767         0.955345        0.008159               26
# 31           0.951662         0.955343        0.004413               27
# 35           0.945619         0.954135        0.006440               28
# 30           0.954683         0.953533        0.011516               29
# 33           0.954683         0.950521        0.010155               30
# 23           0.930514         0.950506        0.012630               31
# 20           0.963746         0.948715        0.015332               32
# 22           0.957704         0.948713        0.009091               33
# 19           0.951662         0.948107        0.005774               34
# 21           0.951662         0.946899        0.015761               35
# 18           0.936556         0.945093        0.020089               36
# 39           0.936556         0.937843        0.008640               37
# 41           0.879154         0.931191        0.027671               38
# 37           0.930514         0.925778        0.009782               39
# 40           0.930514         0.924568        0.004170               40
# 38           0.918429         0.906435        0.022674               41
# 10           0.906344         0.905245        0.015142               42
# 36           0.915408         0.893783        0.015575               43
# 7            0.864048         0.887156        0.024870               44
# 11           0.824773         0.848491        0.026977               45
# 9            0.858006         0.831091        0.067222               46
# 6            0.873112         0.822020        0.044064               47
# 8            0.827795         0.808710        0.017843               48

# %%
print(grid2.best_params_)
# Out:
# {'clf': LogisticRegression(C=100, max_iter=10000, solver='liblinear'), 'reduce_dim': TruncatedSVD(n_components=500, random_state=42), 'vect': CountVectorizer(analyzer=<function nolemma at 0x7f8467a871f0>, min_df=5,
#                 stop_words='english')}
